# %%
## Exercice 1

### Question 2

Les listes Python peuvent être utilisées comme des piles car les opérations
d'ajout et de retrait en fin de liste correspondent aux opérations empiler
et dépiler.

| Opération | En Python sur les listes | Complexité |
|-----------|--------------------------|------------|
| crée_vide | `[]`                     | O(1)       |
| est_vide  | `len(pile) == 0`         | O(1)       |
| empile    | `pile.append(x)`         | O(1)       |
| dépile    | `pile.pop()`             | O(1)       |


j'ai ma liste je peux regarder si elle vide, empiler ajouter un element en bout, dépiler un element de en bout sa ressemble a un comportement de pile

# %%
class Pile :
    def __init__(self) :

    def est_vide(self) :
        return len(self) == 0;²
