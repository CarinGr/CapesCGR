# %% [markdown]
# # TD 1 — Correction du 01/09
#
# [Énoncé](TD1.pdf) · [Cours](cours.ipynb)
#
# ## Exercice 1
#
# ### Question 2
#
# Les listes Python peuvent être utilisées comme des piles car les opérations
# d'ajout et de retrait en fin de liste correspondent aux opérations empiler
# et dépiler.
#
# | Opération | En Python sur les listes | Complexité |
# |-----------|--------------------------|------------|
# | crée_vide | `[]`                     | O(1)       |
# | est_vide  | `len(pile) == 0`         | O(1)       |
# | empile    | `pile.append(x)`         | O(1)       |
# | dépile    | `pile.pop()`             | O(1)       |
#
# **Remarque personnelle :** je peux vérifier si ma liste est vide, ajouter un élément en fin de liste (empiler) et retirer le dernier élément (dépiler). Cela correspond au comportement d’une pile.
#
# ### Question 3 — Implémenter la classe `Pile`
#
# *Ébauche à compléter.*

# %%
class Pile :
    def __init__(self) :

    def est_vide(self) :
        return len(self) == 0;²
